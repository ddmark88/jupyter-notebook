# %% [markdown]
# ## 本程序是基于jieba分词的全文本词频统计

# %% [markdown]
# ## 全文本词频统计的步骤
# + 打开文本
# + 分词
# + 去除停用词（集合的方式）
# + 利用字典，进行词-词频的存储
# + 排序
# + 展示（输出print）

# %%
import jieba

# %%
article = open('sanguo_10.txt','r',encoding = 'utf-8').read() # 打开并读取三国前10回

# %%
dele = {'。','！','？','的','“','”','（','）',' ','》','《','，','董卓','呂布','曹操'} # 手动设计一些停用词和符号

# %%
jieba.add_word('贼') # 加入字典中没有的新词

# %%
words = list(jieba.cut(article)) #结巴分词出来的词汇

# %%
words
# Out:
# ['《',
#  '三国演义',
#  '》',
#  '（',
#  '全',
#  '）',
#  '\n',
#  '\n',
#  '（',
#  '明',
#  '）',
#  '羅',
#  '貫中著',
#  '\n',
#  '\n',
#  ' ',
#  ' ',
#  '\n',
#  '第一回',
#  '\n',
#  '宴桃園',
#  '豪傑',
#  '三',
#  '結義斬黃巾',
#  '英雄',
#  '首',
#  '立功',
#  '\n',
#  '話',
#  '說',
#  '天下',
#  '大勢',
#  '，',
#  '分久必合',
#  '，',
#  '合久必分',
#  '：',
#  '周末',
#  '七國',
#  '分爭',
#  '，',
#  '並',
#  '\n',
#  '入于',
#  '秦',
#  '；',
#  '及',
#  '秦滅',
#  '之',
#  '後',
#  '，',
#  '楚',
#  '、',
#  '漢分爭',
#  '，',
#  '又',
#  '並入',
#  '於',
#  '漢',
#  '；',
#  '漢朝',
#  '自',
#  '高祖',
#  '\n',
#  '斬',
#  '白蛇',
#  '而',
#  '起義',
#  '，',
#  '一統',
#  '天下',
#  '，',
#  '後',
#  '來光',
#  '武中興',
#  '，',
#  '傳至獻帝',
#  '，',
#  '遂',
#  '分',
#  '爲',
#  '\n',
#  '三國',
#  '。',
#  '推其致',
#  '亂',
#  '之',
#  '由',
#  '，',
#  '殆始',
#  '於',
#  '桓',
#  '、',
#  '靈',
#  '二帝',
#  '。',
#  '桓帝',
#  '禁錮',
#  '善類',
#  '，',
#  '崇',
#  '\n',
#  '信',
#  '宦官',
#  '。',
#  '及桓帝',
#  '崩',
#  '，',
#  '靈帝',
#  '即位',
#  '，',
#  '大將',
#  '軍',
#  '竇武',
#  '、',
#  '太傅',
#  '陳',
#  '蕃',
#  '，',
#  '共',
#  '相',
#  '\n',
#  '輔佐',
#  '。',
#  '時有',
#  '宦官',
#  '曹節',
#  '等',
#  '弄權',
#  '，',
#  '竇武',
#  '、',
#  '陳',
#  '蕃',
#  '謀',
#  '誅',
#  '之',
#  '，',
#  '機事',
#  '不密',
#  '，',
#  '\n',
#  '反',
#  '爲',
#  '所害',
#  '。',
#  '中',
#  '涓',
#  '自此',
#  '愈橫',
#  '。',
#  '\n',
#  '建寧',
#  '二年',
#  '四月',
#  '望',
#  '日',
#  '，',
#  '帝禦',
#  '溫德殿',
#  '。',
#  '方',
#  '升座',
#  '，',
#  '殿角',
#  '狂風驟',
#  '起',
#  '，',
#  '\n',
#  '只見',
#  '一條',
#  '大',
#  '青蛇',
#  '，',
#  '從',
#  '梁上',
#  '飛將',
#  '下來',
#  '，',
#  '蟠',
#  '於',
#  '椅上',
#  '。',
#  '帝驚',
#  '倒',
#  '，',
#  '左右',
#  '\n',
#  '急救',
#  '入宮',
#  '，',
#  '百官',
#  '俱奔避',
#  '。',
#  '須臾',
#  '，',
#  '蛇',
#  '不見',
#  '了',
#  '；',
#  '忽然',
#  '大雷',
#  '大雨',
#  '，',
#  '加',
#  '\n',
#  '以',
#  '冰雹',
#  '，',
#  '落到',
#  '半夜',
#  '方止',
#  '，',
#  '壞',
#  '卻',
#  '房屋',
#  '無數',
#  '。',
#  '建寧',
#  '四年',
#  '二月',
#  '，',
#  '洛陽',
#  '\n',
#  '地震',
#  '；',
#  '又',
#  '海水',
#  '泛溢',
#  '，',
#  '沿海居民',
#  '，',
#  '盡',
#  '被',
#  '大浪',
#  '捲',
#  '入海',
#  '中',
#  '。',
#  '光',
#  '和',
#  '元年',
#  '，',
#  '\n',
#  '雌雞化雄',
#  '。',
#  '六月',
#  '朔',
#  '，',
#  '黑氣',
#  '十餘丈',
#  '，',
#  '飛入',
#  '溫德殿',
#  '中',
#  '。',
#  '秋',
#  '七月',
#  '，',
#  '有',
#  '\n',
#  '虹現',
#  '於',
#  '玉堂',
#  '，',
#  '五原',
#  '山岸',
#  '盡',
#  '皆',
#  '崩裂',
#  '。',
#  '種種',
#  '不祥',
#  '，',
#  '非止',
#  '一端',
#  '。',
#  '帝下',
#  '\n',
#  '詔問',
#  '群臣',
#  '以災異',
#  '之',
#  '由',
#  '。',
#  '議',
#  '郎蔡邕',
#  '上',
#  '疏',
#  '，',
#  '以',
#  '爲',
#  '蜺',
#  '墮',
#  '、',
#  '雞化',
#  '，',
#  '乃婦',
#  '\n',
#  '寺',
#  '幹政',
#  '之',
#  '所致',
#  '，',
#  '言',
#  '頗',
#  '切直',
#  '。',
#  '帝覽',
#  '奏',
#  '歎',
#  '息',
#  '，',
#  '因起',
#  '更衣',
#  '。',
#  '曹節',
#  '在',
#  '後',
#  '\n',
#  '竊視',
#  '，',
#  '悉',
#  '宣告',
#  '左右',
#  '；',
#  '遂',
#  '以',
#  '他',
#  '事',
#  '陷邕',
#  '於',
#  '罪',
#  '，',
#  '放歸田',
#  '裏',
#  '。',
#  '後',
#  '張',
#  '讓',
#  '、',
#  '\n',
#  '趙',
#  '忠',
#  '、',
#  '封諝',
#  '、',
#  '段',
#  '珪',
#  '、',
#  '曹節',
#  '、',
#  '侯覽',
#  '、',
#  '蹇',
#  '碩',
#  '、',
#  '程曠',
#  '、',
#  '夏惲',
#  '、',
#  '郭勝十',
#  '\n',
#  '人朋比',
#  '爲',
#  '奸',
#  '，',
#  '號',
#  '爲',
#  '“',
#  '十常侍',
#  '”',
#  '。',
#  '帝尊',
#  '信張',
#  '讓',
#  '，',
#  '呼',
#  '爲',
#  '“',
#  '阿父',
#  '”',
#  '。',
#  '\n',
#  ' ',
#  ' ',
#  '\n',
#  '朝政',
#  '日非',
#  '，',
#  '以致',
#  '天下人',
#  '心思',
#  '亂',
#  '，',
#  '盜賊',
#  '蜂起',
#  '。',
#  '\n',
#  '時',
#  '巨鹿郡',
#  '有',
#  '兄弟',
#  '三人',
#  '：',
#  '一名',
#  '張角',
#  '，',
#  '一名',
#  '張寶',
#  '，',
#  '一名',
#  '張梁',
#  '。',
#  '\n',
#  '那',
#  '張角本',
#  '是',
#  '個',
#  '不',
#  '第',
#  '秀才',
#  '，',
#  '因入',
#  '山',
#  '采藥',
#  '，',
#  '遇一',
#  '老人',
#  '，',
#  '碧眼',
#  '童',
#  '顔',
#  '，',
#  '\n',
#  '手',
#  '執藜',
#  '杖',
#  '，',
#  '喚角',
#  '至',
#  '一洞',
#  '中',
#  '，',
#  '以天書',
#  '三卷',
#  '授',
#  '之',
#  '，',
#  '曰',
#  '：',
#  '“',
#  '此名',
#  '《',
#  '太',
#  '\n',
#  '平要術',
#  '》',
#  '。',
#  '汝得',
#  '之',
#  '，',
#  '當代天',
#  '宣化',
#  '，',
#  '普',
#  '救世',
#  '人',
#  '。',
#  '若萌',
#  '異心',
#  '，',
#  '必獲',
#  '\n',
#  '惡報',
#  '。',
#  '”',
#  '角拜問',
#  '姓名',
#  '。',
#  '老人',
#  '曰',
#  '：',
#  '“',
#  '吾',
#  '乃',
#  '南華',
#  '老仙',
#  '也',
#  '。',
#  '”',
#  '言',
#  '訖',
#  '，',
#  '\n',
#  '化陣',
#  '清風',
#  '而',
#  '去',
#  '。',
#  '角得',
#  '此書',
#  '，',
#  '曉夜',
#  '攻習',
#  '，',
#  '能呼',
#  '風喚',
#  '雨',
#  '，',
#  '號',
#  '爲',
#  '“',
#  '太',
#  '\n',
#  '平道人',
#  '”',
#  '。',
#  '\n',
#  '中平',
#  '元年',
#  '正月',
#  '內',
#  '，',
#  '疫氣',
#  '流行',
#  '，',
#  '張角',
#  '散施',
#  '符水',
#  '，',
#  '爲',
#  '人',
#  '治病',
#  '，',
#  '\n',
#  '自稱',
#  '“',
#  '大賢良師',
#  '”',
#  '。',
#  '角有',
#  '徒弟',
#  '五百余',
#  '人',
#  '，',
#  '雲遊',
#  '四方',
#  '，',
#  '皆',
#  '能書符',
#  '\n',
#  '念咒',
#  '。',
#  '次後徒',
#  '衆',
#  '日',
#  '多',
#  '，',
#  '角乃立',
#  '三十六方',
#  '，',
#  '大方',
#  '萬餘人',
#  '，',
#  '小方',
#  '六',
#  '\n',
#  '七千',
#  '，',
#  '各立',
#  '渠帥',
#  '，',
#  '稱',
#  '爲',
#  '將軍',
#  '；',
#  '訛言',
#  '：',
#  '“',
#  '蒼天',
#  '已',
#  '死',
#  '，',
#  '黃',
#  '天當立',
#  '；',
#  '\n',
#  '歲',
#  '在',
#  '甲子',
#  '，',
#  '天下',
#  '大吉',
#  '。',
#  '”',
#  '令人',
#  '各以',
#  '白土',
#  '書',
#  '“',
#  '甲子',
#  '”',
#  '二字',
#  '於',
#  '家中',
#  '\n',
#  '大門',
#  '上',
#  '。',
#  '青',
#  '、',
#  '幽',
#  '、',
#  '徐',
#  '、',
#  '冀',
#  '、',
#  '荊',
#  '、',
#  '揚',
#  '、',
#  '兗',
#  '、',
#  '豫八州',
#  '之',
#  '人',
#  '，',
#  '家家',
#  '侍',
#  '\n',
#  '奉大賢良師',
#  '張角',
#  '名字',
#  '。',
#  '角遣',
#  '其党馬元義',
#  '，',
#  '暗',
#  '齎',
#  '金帛',
#  '，',
#  '結交中',
#  '涓',
#  '\n',
#  '封諝',
#  '，',
#  '以',
#  '爲',
#  '內應',
#  '。',
#  '角',
#  '與',
#  '二角',
#  '商議',
#  '曰',
#  '：',
#  '“',
#  '至',
#  '難得者',
#  '，',
#  '民心',
#  '也',
#  '。',
#  '今',
#  '\n',
#  '民心',
#  '已順',
#  '，',
#  '若',
#  '不',
#  '乘勢',
#  '取',
#  '天下',
#  '，',
#  '誠',
#  '爲',
#  '可惜',
#  '。',
#  '”',
#  '遂',
#  '一面',
#  '私造',
#  '黃',
#  '旗',
#  '，',
#  '\n',
#  '約期',
#  '舉事',
#  '；',
#  '一面',
#  '使',
#  '弟子',
#  '唐周',
#  '，',
#  '馳書報',
#  '封諝',
#  '。',
#  '唐周',
#  '乃徑',
#  '赴',
#  '省',
#  '中告',
#  '\n',
#  '變',
#  '。',
#  '帝召大將',
#  '軍何',
#  '進調',
#  '兵',
#  '擒馬元義',
#  '，',
#  '斬',
#  '之',
#  '；',
#  '次收',
#  '封諝',
#  '等',
#  '一干人',
#  '\n',
#  '下獄',
#  '。',
#  '張角聞',
#  '知事',
#  '露',
#  '，',
#  '星夜',
#  '舉兵',
#  '，',
#  '自稱',
#  '“',
#  '天公',
#  '將軍',
#  '”',
#  '，',
#  '張寶稱',
#  '\n',
#  '“',
#  '地公將',
#  '軍',
#  '”',
#  '，',
#  '張梁',
#  '稱',
#  '“',
#  '人公將',
#  '軍',
#  '”',
#  '，',
#  '申言',
#  '於',
#  '衆',
#  '曰',
#  '：',
#  '“',
#  '今漢運',
#  '\n',
#  '將終',
#  '，',
#  '大聖人出',
#  '。',
#  '汝',
#  '等',
#  '皆宜',
#  '順天',
#  '從',
#  '正',
#  '，',
#  '以樂',
#  '太平',
#  '。',
#  '”',
#  '四方',
#  '百姓',
#  '，',
#  '\n',
#  '裹',
#  '黃',
#  '巾',
#  '從',
#  '張角',
#  '反者',
#  '四五十',
#  '萬',
#  '。',
#  '賊勢',
#  '浩大',
#  '，',
#  '官軍望',
#  '風而靡',
#  '。',
#  '何進',
#  '\n',
#  '奏帝',
#  '火速',
#  '降詔',
#  '，',
#  '令',
#  '各',
#  '處備',
#  '禦',
#  '，',
#  '討賊',
#  '立功',
#  '；',
#  '一面',
#  '遣',
#  '中郎將',
#  '盧植',
#  '、',
#  '\n',
#  '皇甫嵩',
#  '、',
#  '朱雋',
#  '，',
#  '各引',
#  '精兵',
#  '，',
#  '分',
#  '三路',
#  '討之',
#  '。',
#  '\n',
#  '且',
#  '說',
#  '張角',
#  '一',
#  '軍',
#  '，',
#  '前犯',
#  '幽州',
#  '界分',
#  '。',
#  '幽州',
#  '太守',
#  '劉焉',
#  '，',
#  '乃',
#  '江夏',
#  '竟',
#  '\n',
#  '陵',
#  '人氏',
#  '，',
#  '漢魯恭王',
#  '之',
#  '後',
#  '也',
#  '。',
#  '當時聞',
#  '得',
#  '賊',
#  '兵將',
#  '至',
#  '，',
#  '召',
#  '校尉',
#  '鄒靖計',
#  '\n',
#  ' ',
#  ' ',
#  '\n',
#  '議',
#  '。',
#  '靖',
#  '曰',
#  '：',
#  '“',
#  '賊',
#  '兵',
#  '衆',
#  '，',
#  '我兵',
#  '寡',
#  '，',
#  '明公宜',
#  '作速',
#  '招軍應',
#  '敵',
#  '。',
#  '”',
#  '劉焉',
#  '\n',
#  '然其',
#  '說',
#  '，',
#  '隨即',
#  '出榜',
#  '招募',
#  '義兵',
#  '。',
#  '\n',
#  '榜文',
#  '行到',
#  '涿縣',
#  '，',
#  '引出',
#  '涿縣',
#  '中',
#  '一個',
#  '英雄',
#  '。',
#  '那人',
#  '不',
#  '甚好',
#  '讀書',
#  '，',
#  '\n',
#  '性',
#  '寬',
#  '和',
#  '，',
#  '寡言',
#  '語',
#  '，',
#  '喜怒不形',
#  '於',
#  '色',
#  '。',
#  '素有',
#  '大志',
#  '，',
#  '專好',
#  '結交',
#  '天下',
#  '豪',
#  '\n',
#  '傑',
#  '。',
#  '生得',
#  '身長',
#  '七尺',
#  '五寸',
#  '，',
#  '兩',
#  '耳垂',
#  '肩',
#  '，',
#  '雙手',
#  '過膝',
#  '，',
#  '目能',
#  '自顧',
#  '其耳',
#  '，',
#  '\n',
#  '面如冠玉',
#  '，',
#  '唇',
#  '若',
#  '塗脂',
#  '。',
#  '—',
#  '—',
#  '中山',
#  '靖王',
#  '劉勝',
#  '之',
#  '後',
#  '，',
#  '漢景帝',
#  '閣',
#  '下',
#  '玄',
#  '\n',
#  '孫',
#  '—',
#  '—',
#  '姓劉',
#  '，',
#  '名備',
#  '，',
#  '字',
#  '玄德',
#  '。',
#  '昔',
#  '劉勝之子',
#  '劉貞',
#  '，',
#  '漢武時',
#  '封',
#  '涿鹿',
#  '\n',
#  '亭',
#  '侯',
#  '，',
#  '後',
#  '坐',
#  '酎',
#  '金失侯',
#  '，',
#  '因此',
#  '遺',
#  '這',
#  '一枝',
#  '在',
#  '涿縣',
#  '。',
#  '玄德祖',
#  '劉雄',
#  ...]

# %% [markdown]
# ### 字典

# %%
articleDict = {} # 这是一个字典，准备词-词频的保存

# %% [markdown]
# ### 集合（数据结构的一种）

# %%
articleSet = set(words)-dele

# %%
articleSet
# Out:
# {'如不勝',
#  '饑',
#  '若蒙',
#  '操告',
#  '來光',
#  '荼',
#  '何須',
#  '金鼓',
#  '布同',
#  '稠',
#  '叱',
#  '無謀',
#  '關外',
#  '之車',
#  '姬兮命',
#  '虐者',
#  '何後亦怒',
#  '勒兵',
#  '蒯良出',
#  '第',
#  '張寶勢',
#  '火炭',
#  '名爵',
#  '討張',
#  '營造',
#  '之聲',
#  '頭戴',
#  '操大喜',
#  '點軍司',
#  '過山嶺',
#  '之禮',
#  '滅族',
#  '指林',
#  '否德',
#  '商議',
#  '又名',
#  '盡閉',
#  '簇擁入',
#  '紹遂移',
#  '公且',
#  '馥',
#  '王匡',
#  '分花拂柳',
#  '如飛',
#  '不要',
#  '傳',
#  '忽然',
#  '擅',
#  '越大',
#  '合久必分',
#  '千乘',
#  '卓頭',
#  '便勒',
#  '並後妃',
#  '助惡',
#  '探知',
#  '受劍鋒',
#  '之民',
#  '方圓',
#  '命公孫瓚且',
#  '盡降',
#  '不飛',
#  '叔侄',
#  '玄德拜',
#  '詳',
#  '歌舞',
#  '老仙',
#  '敬酒',
#  '住陽城',
#  '‘',
#  '九十',
#  '火置',
#  '聲大震',
#  '辛評',
#  '論惑',
#  '傳至',
#  '檢點',
#  '侵犯',
#  '著將',
#  '字元',
#  '旗',
#  '大小',
#  '內省',
#  '伏路',
#  '先',
#  '難保',
#  '屈己',
#  '偷開城',
#  '布對',
#  '一婦',
#  '無大將',
#  '儒急入',
#  '功在',
#  '武關',
#  '木雕',
#  '關迎',
#  '將此',
#  '變',
#  '掃清',
#  '公恣其',
#  '二兄要',
#  '忽',
#  '應光',
#  '赴宴',
#  '倡亂',
#  '絕口',
#  '夜',
#  '表然',
#  '限制',
#  '半身',
#  '誰識',
#  '寺',
#  '資少',
#  '張鈞',
#  '以定後事',
#  '孝元',
#  '相助',
#  '死',
#  '常刑',
#  '豫八州',
#  '家產',
#  '床',
#  '秦',
#  '卓氣力',
#  '春日',
#  '村民',
#  '展',
#  '國之',
#  '便喚',
#  '當對',
#  '不題',
#  '捐宗廟',
#  '周毖曰',
#  '二',
#  '朔',
#  '字曼成',
#  '隻',
#  '下寨',
#  '殘破',
#  '彼營',
#  '瓚',
#  '酒至',
#  '竟',
#  '納貂蟬',
#  '齊潑',
#  '以前',
#  '自專大權',
#  '參錄',
#  '除別',
#  '引軍來',
#  '將徐榮',
#  '風忽起',
#  '認得',
#  '姓典',
#  '心變',
#  '騎飛',
#  '山中',
#  '名禁',
#  '免冠',
#  '私情',
#  '操不顧',
#  '更助',
#  '免罪',
#  '入見伯奢',
#  '玄德公',
#  '舉稱',
#  '釋放',
#  '隗曰',
#  '楚文王',
#  '迎戰',
#  '蟬方',
#  '忻喜',
#  '我三人義',
#  '一將',
#  '卓拔',
#  '李典',
#  '不行',
#  '事必',
#  '酒數',
#  '酸棗',
#  '突火',
#  '後將',
#  '洞庭',
#  '今興兵',
#  '白土',
#  '卓趕',
#  '罷其官',
#  '副將',
#  '懷疑',
#  '一陣',
#  '老母',
#  '初出',
#  '萬戶',
#  '署縣',
#  '來長',
#  '邪',
#  '弑',
#  '操乃',
#  '善人',
#  '堂堂',
#  '掃除',
#  '大義',
#  '孟津',
#  '此四人',
#  '前失',
#  '車上',
#  '前過',
#  '操因',
#  '海水',
#  '並無雞',
#  '洛陽',
#  '之助乎',
#  '鋸',
#  '虎步',
#  '王登殿',
#  '居喪慢',
#  '降者',
#  '幼',
#  '儀亭',
#  '數萬級',
#  '紹大怒',
#  '憤恨',
#  '悔之晚矣',
#  '即起',
#  '狼',
#  '結親',
#  '龍',
#  '重扶',
#  '宅',
#  '進發',
#  '軍法',
#  '孫堅出',
#  '上關',
#  '嵩慌',
#  '營寨',
#  '遂解',
#  '自退',
#  '汝子乎',
#  '張殺入',
#  '隱居琅',
#  '一槍',
#  '人棄',
#  '倘若',
#  '所獲',
#  '今紹',
#  '重權',
#  '玄德幼',
#  '百餘',
#  '謙本',
#  '都亭侯',
#  '何詔',
#  '棄之',
#  '武中興',
#  '桓',
#  '見督',
#  '袁氏',
#  '英勇',
#  '一一',
#  '落地',
#  '願得',
#  '數',
#  '汝來',
#  '兵無戰心',
#  '布拔',
#  '興師',
#  '此書',
#  '誓欲掃',
#  '搜看',
#  '打出',
#  '堅就脫',
#  '殘',
#  '人情',
#  '季佐',
#  '左',
#  '鸞',
#  '不如',
#  '橋邊',
#  '還屍',
#  '徑入後堂',
#  '驚伏',
#  '跨江涉',
#  '奪將',
#  '竊視',
#  '表奏',
#  '布謝',
#  '超',
#  '望車',
#  '紹引兵',
#  '只宜',
#  '天畫',
#  '放箭',
#  '’',
#  '回言',
#  '向晚',
#  '稠大驚',
#  '焉用',
#  '抱頭',
#  '分別',
#  '隱匿',
#  '今謀',
#  '操見紹',
#  '備言',
#  '於門',
#  '靈柩',
#  '金甲錦袍',
#  '零落',
#  '池中',
#  '一醉',
#  '分王',
#  '待人',
#  '耿',
#  '燕',
#  '納交反',
#  '何疑',
#  '樹下',
#  '寢則',
#  '鄭泰諫',
#  '天色',
#  '急救',
#  '俱奔避',
#  '州牧',
#  '然後用計',
#  '小民',
#  '求赦',
#  '堂',
#  '在手',
#  '祝壽',
#  '不分',
#  '姓孫',
#  '聲猶未',
#  '面無事乎',
#  '莊前',
#  '親女',
#  '騎弘馬',
#  '一',
#  '不論',
#  '劉虞平寇',
#  '時陳宮',
#  '下安',
#  '其功',
#  '追',
#  '寬懷',
#  '叱布',
#  '彧',
#  '提防',
#  '王者',
#  '斬',
#  '腸',
#  '非仇',
#  '身之計',
#  '頭上',
#  '質',
#  '年方',
#  '已露',
#  '農王',
#  '倘',
#  '蟬許',
#  '不定',
#  '奏何',
#  '駢集',
#  '歇',
#  '名曰',
#  '如旱',
#  '把住',
#  '痊',
#  '城門外',
#  '先皇',
#  '定孫',
#  '俱',
#  '操覺',
#  '回頭',
#  '笙簧',
#  '元年',
#  '滅門',
#  '不在側',
#  '紹等懼',
#  '可輕動',
#  '良言',
#  '降賊',
#  '寸功',
#  '軍自姓',
#  '布大怒',
#  '駕西幸',
#  '覆姓',
#  '太猛',
#  '將何',
#  '城郭',
#  '悉皆',
#  '無道',
#  '反國',
#  '念曰',
#  '先鋒',
#  '汝之力',
#  '切勿',
#  '高坡',
#  '禽獸',
#  '更衣',
#  '瞞',
#  '本漢室',
#  '韓馥之權',
#  '背國',
#  '田豐慌',
#  '此來者',
#  '而別',
#  '棄官',
#  '劉勝',
#  '便',
#  '細詳',
#  '行路',
#  '忽折',
#  '勸卓',
#  '袁遺',
#  '不語',
#  '左右',
#  '此長',
#  '事濟',
#  '其清者',
#  '進調',
#  '直進',
#  '布交厚',
#  '元老',
#  '犯禁',
#  '以將',
#  '資財',
#  '孝',
#  '三十六年',
#  '丞',
#  '恐惹後人',
#  '犯者',
#  '坐中',
#  '稱謝',
#  '諭以',
#  '非謙罪',
#  '無限',
#  '孤客',
#  '母時',
#  '武士',
#  '各置',
#  '發箭',
#  '知',
#  '祖',
#  '震開',
#  '故托言',
#  '尚自',
#  '都督',
#  '此天亡',
#  '背主',
#  '表',
#  '結義斬黃巾',
#  '堅背',
#  '奔涼州',
#  '彼兵',
#  '置酒',
#  '深',
#  '韓遂',
#  '劉焉',
#  '無得',
#  '恰待',
#  '州郡',
#  '使廷臣',
#  '殷勤',
#  '就席間',
#  '裂汝以',
#  '帝大驚',
#  '願入',
#  '發冠',
#  '車騎將',
#  '面',
#  '暗',
#  '百寶妝',
#  '封',
#  '于',
#  '呂布將',
#  '顯官',
#  '今先害',
#  '黎民',
#  '應付',
#  '感恩',
#  '宴之處',
#  '上書',
#  '皇',
#  '出奇',
#  '先伏',
#  '塚',
#  '盛',
#  '帝令',
#  '趕出',
#  '各立',
#  '沽',
#  '巨',
#  '戲汝',
#  '實',
#  '淪喪',
#  '可請汝兄',
#  '出戰',
#  '封弟',
#  '責之',
#  '北宮',
#  '夜哭',
#  '赦',
#  '關純伏',
#  '國母',
#  '入獻',
#  '諸侯興兵',
#  '見原',
#  '廝殺',
#  '帝尊',
#  '至華陰',
#  '再議',
#  '必順',
#  '此天助',
#  '殺得',
#  '日誤',
#  '然後圖',
#  '聽',
#  '良立',
#  '張飛性',
#  '劫寨',
#  '孫堅次',
#  '而致',
#  '謀士逢紀',
#  '卓大',
#  '不勝',
#  '姓祖',
#  '何相戲',
#  '盡棄',
#  '北平',
#  '滿地',
#  '龔景',
#  '錯下',
#  '乃聚',
#  '令良',
#  '情',
#  '問其',
#  '沛國',
#  '喝退',
#  '牧丹亭',
#  '廟堂',
#  '失此',
#  '自',
#  '出血',
#  '王協',
#  '英雄',
#  '今上',
#  '整頓',
#  '儒綁',
#  '一行',
#  '天使',
#  '莫敢',
#  '共寢',
#  '死戰',
#  '部',
#  '城門',
#  '卓所立',
#  '入宮',
#  '泥',
#  '昔',
#  '曹公破',
#  '成群',
#  '可',
#  '何強',
#  '罷兵',
#  '之處',
#  '卓賊',
#  '舊日',
#  '操聞言',
#  '懼怕',
#  '盜賊並',
#  '解之',
#  '當有',
#  '貂蟬手',
#  '五百',
#  '兩軍齊',
#  '病體',
#  '軍士',
#  '師事',
#  '下令',
#  '宦官',
#  '九五',
#  '勇略',
#  '當先',
#  '誠不若加',
#  '滿',
#  '進之謀',
#  '引貂蟬',
#  '聽政',
#  '進兵',
#  '同扶國家',
#  '頓',
#  '半酣',
#  '回報',
#  '病不出',
#  '刀斧手',
#  '布無心',
#  '收兵',
#  '之能',
#  '涓埃',
#  '卓聞言',
#  '勝言',
#  '擁入',
#  '引軍暫',
#  '名蓋',
#  '活捉',
#  '不惜',
#  '龍床',
#  '心',
#  '寇之志',
#  '盔',
#  '帝下',
#  '猛將',
#  '若何',
#  '入後園',
#  '連馬騰',
#  '躍馬',
#  '不肯',
#  '可乘勢',
#  '帳',
#  '及甲',
#  '不爛',
#  '出園門',
#  '向前',
#  '乃差',
#  '兒將',
#  '之臣',
#  '無計',
#  '喜拜謝',
#  '偎倚',
#  '督郵先',
#  '陶謙殺',
#  '來京',
#  '徒弟',
#  '六月',
#  '將軍何',
#  '廣額',
#  '與關',
#  '汝若要',
#  '五丈',
#  '操軍大敗',
#  '太后',
#  '力扶漢',
#  '鄄城',
#  '祖大敗',
#  '進而回',
#  '峴',
#  '樊稠去',
#  '官惜',
#  '各設',
#  '本初',
#  '見利',
#  '人築',
#  '乃東',
#  '雄軍只',
#  '操令',
#  '接',
#  '高壘',
#  '急進',
#  '涿郡',
#  '見機',
#  '上街',
#  '洪爐',
#  '宜承洪業',
#  '巧使',
#  '領軍出',
#  '願死',
#  '四子',
#  '陶謙遊',
#  '李儒至',
#  '許攸',
#  '公取',
#  '三公',
#  '圖形',
#  '母',
#  '章殿',
#  '傍邊',
#  '氣實',
#  '聞將',
#  '回寓',
#  '新',
#  '來代將',
#  '始初',
#  '軍殺',
#  '截孫堅',
#  '妃',
#  '勝於養',
#  '接入',
#  '義兵',
#  '將軍一見',
#  '何言無奈',
#  '終成',
#  '矛',
#  '直殺',
#  '上馬徑',
#  '吹',
#  '虔共薦',
#  '依',
#  '能呼',
#  '項',
#  '棄職',
#  '卓將',
#  '認玄德',
#  '暗使',
#  '老夫',
#  '口',
#  '張而問',
#  '以明',
#  '社稷',
#  '果然',
#  '不若棄',
#  '討區星',
#  '紹驚得',
#  '先父',
#  '稟',
#  '度日如年',
#  '如車',
#  '懼',
#  '遠望',
#  '中常',
#  '布幾自誤',
#  '帝非帝',
#  '字伯',
#  '牛輔',
#  '延平',
#  '張虎',
#  '無虞',
#  '活矣',
#  '觀',
#  '病',
#  '自戰敗',
#  '只理會',
#  '當下',
#  '過者',
#  '昔高',
#  '反丁',
#  '角得',
#  '臯',
#  '問',
#  '董後曰',
#  '曹德及',
#  '曹豹',
#  '乃同',
#  '三遷',
#  '不用',
#  '中部',
#  '以言撫慰',
#  '此關',
#  '淚如泉',
#  '骨悉',
#  '盛德',
#  '不必',
#  '帳下',
#  '卻常會',
#  '異姓',
#  '之大怒',
#  '縛來',
#  '立太子',
#  '問門吏',
#  '玄德遠',
#  '何高見',
#  '郭勝四個',
#  '此玉',
#  '百花',
#  '騎花',
#  '先將汝許',
#  '某願助',
#  '董氏宗',
#  '巨富',
#  '放入',
#  '疏財仗',
#  '諸侯皆言',
#  '除洛陽',
#  '未准',
#  '堅令',
#  '汝何',
#  '已事',
#  '張投',
#  '侍衛',
#  '機事',
#  '伯喈',
#  '堅隨即',
#  '張邈',
#  '領兵拔',
#  '鎖著',
#  '屯弘農',
#  '召集',
#  '薦',
#  '布怒',
#  '聽聞',
#  '兄醉',
#  '虎體',
#  '難免',
#  '漸漸',
#  '群臣',
#  '近侍',
#  '時賊',
#  '次收',
#  '玉堂',
#  '布入',
#  '癰',
#  '怨',
#  '非命',
#  '贈金銀',
#  '其党馬元義',
#  '允非',
#  '言公鴆殺',
#  '悶酒',
#  '徑入',
#  '唐周',
#  '衣甲',
#  '便問',
#  '悲切',
#  '問劉表借',
#  '以助',
#  '奔逃',
#  '驅去',
#  '密室',
#  '日若',
#  '安之至',
#  '蟬出',
#  '詞贊',
#  '見布來',
#  '公共',
#  '車後厲',
#  '方欲',
#  '漫天',
#  '特宣大將',
#  '平原',
#  '一子一女',
#  '其如',
#  '奉獻',
#  '方驚避',
#  '久住',
#  '促裝',
#  '樂',
#  '駭',
#  '鳴金',
#  '十次',
#  '尊意',
#  '宰',
#  '右有翼德',
#  '民心',
#  '誓',
#  '其妹',
#  '有濟',
#  '善類',
#  '孤陋',
#  '公道',
#  '不須',
#  '義引',
#  '一丈',
#  '上建白',
#  '遜',
#  '退入',
#  '雖然',
#  '今匿',
#  '相逼鄰',
#  '氣高',
#  '市',
#  '門外',
#  '紅光',
#  '允捧觴',
#  '張伏',
#  '朝賀',
#  '潘鳳',
#  '旗竿',
#  '提縣',
#  '兵圍',
#  '口稱',
#  '召',
#  '背後喊',
#  '一處',
#  '老',
#  '飛下',
#  '相並',
#  '定州',
#  '少年',
#  '兄長',
#  '汝視',
#  '道人',
#  '可立',
#  '兩傍',
#  '起居',
#  '肅拜',
#  '手攀曲欄',
#  '低',
#  '中石',
#  '不意',
#  '也',
#  '勸',
#  '仰面',
#  '有罪',
#  '布軍與戰',
#  '讒言',
#  '王允運',
#  '遮道',
#  '宣卓入',
#  '司徒',
#  '西衝',
#  '剿戮',
#  '鞭大罵',
#  '便出',
#  '捉拿',
#  '近卓',
#  '召三',
#  '牛輔喚',
#  '近日',
#  '四海',
#  '任',
#  '相繼而入',
#  '此賊',
#  '施小策',
#  '趕至翠花樓',
#  '軍吏',
#  '付布',
#  '結連黃巾',
#  '棄弓',
#  '休',
#  '速決',
#  '深深',
#  '有',
#  '自寵',
#  '進至長',
#  '殺此',
#  '奔入',
#  '傳國玉璽',
#  '殘虐',
#  '沈吟',
#  '教',
#  '萬人',
#  '使人密',
#  '當日',
#  '越來',
#  '過去',
#  '璽',
#  '食',
#  '迸流',
#  '一驚',
#  '大叫',
#  '沙汰',
#  '郵之頸',
#  '必生',
#  '朝門',
#  '韓遂勒馬',
#  '卓婿',
#  '封太尉',
#  '飛馬徑',
#  '今可',
#  '小方',
#  '射時',
#  '秀才',
#  '卓必',
#  '然身',
#  '藏刀',
#  '南陽',
#  '既然',
#  '現居何',
#  '未有',
#  '欲戰',
#  '亦聘',
#  '棄萬乘',
#  '打死',
#  '羽',
#  '羨',
#  '氏',
#  '眼睛',
#  '狂風',
#  '雋班師',
#  '鮑信',
#  '右突',
#  '人稱',
#  '可破群',
#  '攻習',
#  '反',
#  '中設',
#  '創殿',
#  '軍馬列',
#  '我奮',
#  '大尉',
#  '司空',
#  '窺見',
#  '浩大',
#  '髯',
#  '仗',
#  '聲美譽',
#  '平要術',
#  '園門外',
#  '將欲何',
#  '應允',
#  '氣象',
#  '差',
#  '汝分',
#  '率民',
#  '血',
#  '文醜',
#  '忘恩',
#  '軍士圍',
#  '引軍而出',
#  '本部',
#  '相近',
#  '川',
#  '不佑',
#  ...}

# %%
# 因为采用的是循环的方法，把所有的词都循环一遍，长度大于1，所以速度很慢！

# %%
for w in articleSet:
    if len(w)>1:
        articleDict[w] = words.count(w)  # 字典的key-value配对

# %%
articleDict
# Out:
# {'如不勝': 1,
#  '若蒙': 1,
#  '操告': 1,
#  '來光': 1,
#  '何須': 2,
#  '金鼓': 3,
#  '布同': 1,
#  '無謀': 2,
#  '關外': 2,
#  '之車': 1,
#  '姬兮命': 1,
#  '虐者': 1,
#  '何後亦怒': 1,
#  '勒兵': 2,
#  '蒯良出': 1,
#  '張寶勢': 2,
#  '火炭': 1,
#  '名爵': 1,
#  '討張': 1,
#  '營造': 1,
#  '之聲': 5,
#  '頭戴': 1,
#  '操大喜': 3,
#  '點軍司': 1,
#  '過山嶺': 1,
#  '之禮': 1,
#  '滅族': 3,
#  '指林': 1,
#  '否德': 1,
#  '商議': 25,
#  '又名': 1,
#  '盡閉': 1,
#  '簇擁入': 1,
#  '紹遂移': 1,
#  '公且': 1,
#  '王匡': 6,
#  '分花拂柳': 1,
#  '如飛': 1,
#  '不要': 1,
#  '忽然': 8,
#  '越大': 1,
#  '合久必分': 1,
#  '千乘': 1,
#  '卓頭': 1,
#  '便勒': 1,
#  '並後妃': 1,
#  '助惡': 1,
#  '探知': 1,
#  '受劍鋒': 1,
#  '之民': 1,
#  '方圓': 1,
#  '命公孫瓚且': 1,
#  '盡降': 1,
#  '不飛': 1,
#  '叔侄': 1,
#  '玄德拜': 1,
#  '歌舞': 4,
#  '老仙': 1,
#  '敬酒': 1,
#  '住陽城': 1,
#  '九十': 1,
#  '火置': 1,
#  '聲大震': 2,
#  '辛評': 1,
#  '論惑': 1,
#  '傳至': 1,
#  '檢點': 1,
#  '侵犯': 2,
#  '著將': 1,
#  '字元': 1,
#  '大小': 2,
#  '內省': 1,
#  '伏路': 1,
#  '難保': 1,
#  '屈己': 1,
#  '偷開城': 1,
#  '布對': 1,
#  '一婦': 1,
#  '無大將': 1,
#  '儒急入': 1,
#  '功在': 1,
#  '武關': 1,
#  '木雕': 1,
#  '關迎': 1,
#  '將此': 2,
#  '掃清': 1,
#  '公恣其': 1,
#  '二兄要': 1,
#  '應光': 1,
#  '赴宴': 2,
#  '倡亂': 1,
#  '絕口': 2,
#  '表然': 1,
#  '限制': 1,
#  '半身': 1,
#  '誰識': 2,
#  '資少': 1,
#  '張鈞': 2,
#  '以定後事': 1,
#  '孝元': 1,
#  '相助': 4,
#  '常刑': 1,
#  '豫八州': 1,
#  '家產': 1,
#  '卓氣力': 1,
#  '春日': 1,
#  '村民': 1,
#  '國之': 1,
#  '便喚': 1,
#  '當對': 1,
#  '不題': 1,
#  '捐宗廟': 1,
#  '周毖曰': 1,
#  '字曼成': 1,
#  '下寨': 1,
#  '殘破': 1,
#  '彼營': 1,
#  '酒至': 2,
#  '納貂蟬': 1,
#  '齊潑': 1,
#  '以前': 2,
#  '自專大權': 1,
#  '參錄': 1,
#  '除別': 1,
#  '引軍來': 1,
#  '將徐榮': 1,
#  '風忽起': 2,
#  '認得': 2,
#  '姓典': 1,
#  '心變': 2,
#  '騎飛': 1,
#  '山中': 3,
#  '名禁': 1,
#  '免冠': 1,
#  '私情': 1,
#  '操不顧': 1,
#  '更助': 2,
#  '免罪': 1,
#  '入見伯奢': 1,
#  '玄德公': 1,
#  '舉稱': 1,
#  '釋放': 1,
#  '隗曰': 1,
#  '楚文王': 1,
#  '迎戰': 6,
#  '蟬方': 1,
#  '忻喜': 1,
#  '我三人義': 1,
#  '一將': 9,
#  '卓拔': 1,
#  '李典': 2,
#  '不行': 1,
#  '事必': 1,
#  '酒數': 1,
#  '酸棗': 1,
#  '突火': 1,
#  '後將': 1,
#  '洞庭': 1,
#  '今興兵': 1,
#  '白土': 1,
#  '卓趕': 1,
#  '罷其官': 1,
#  '副將': 1,
#  '懷疑': 1,
#  '一陣': 4,
#  '老母': 1,
#  '初出': 3,
#  '萬戶': 1,
#  '署縣': 1,
#  '來長': 2,
#  '操乃': 1,
#  '善人': 1,
#  '堂堂': 1,
#  '掃除': 1,
#  '大義': 1,
#  '孟津': 1,
#  '此四人': 1,
#  '前失': 1,
#  '車上': 2,
#  '前過': 1,
#  '操因': 1,
#  '海水': 1,
#  '並無雞': 1,
#  '洛陽': 9,
#  '之助乎': 1,
#  '虎步': 1,
#  '王登殿': 1,
#  '居喪慢': 1,
#  '降者': 2,
#  '儀亭': 4,
#  '數萬級': 1,
#  '紹大怒': 1,
#  '憤恨': 1,
#  '悔之晚矣': 1,
#  '即起': 1,
#  '結親': 2,
#  '重扶': 1,
#  '進發': 2,
#  '軍法': 1,
#  '孫堅出': 1,
#  '上關': 1,
#  '嵩慌': 1,
#  '營寨': 1,
#  '遂解': 2,
#  '自退': 1,
#  '汝子乎': 1,
#  '張殺入': 1,
#  '隱居琅': 1,
#  '一槍': 2,
#  '人棄': 1,
#  '倘若': 1,
#  '所獲': 1,
#  '今紹': 1,
#  '重權': 2,
#  '玄德幼': 1,
#  '百餘': 1,
#  '謙本': 1,
#  '都亭侯': 1,
#  '何詔': 1,
#  '棄之': 1,
#  '武中興': 1,
#  '見督': 1,
#  '袁氏': 2,
#  '英勇': 2,
#  '一一': 1,
#  '落地': 1,
#  '願得': 1,
#  '汝來': 2,
#  '兵無戰心': 2,
#  '布拔': 1,
#  '興師': 2,
#  '此書': 1,
#  '誓欲掃': 1,
#  '搜看': 1,
#  '打出': 1,
#  '堅就脫': 1,
#  '人情': 3,
#  '季佐': 1,
#  '不如': 8,
#  '橋邊': 2,
#  '還屍': 1,
#  '徑入後堂': 1,
#  '驚伏': 1,
#  '跨江涉': 1,
#  '奪將': 1,
#  '竊視': 1,
#  '表奏': 1,
#  '布謝': 2,
#  '望車': 1,
#  '紹引兵': 1,
#  '只宜': 1,
#  '天畫': 1,
#  '放箭': 3,
#  '回言': 2,
#  '向晚': 1,
#  '稠大驚': 1,
#  '焉用': 1,
#  '抱頭': 1,
#  '分別': 1,
#  '隱匿': 1,
#  '今謀': 1,
#  '操見紹': 1,
#  '備言': 1,
#  '於門': 1,
#  '靈柩': 1,
#  '金甲錦袍': 1,
#  '零落': 1,
#  '池中': 1,
#  '一醉': 1,
#  '分王': 1,
#  '待人': 2,
#  '納交反': 1,
#  '何疑': 1,
#  '樹下': 1,
#  '寢則': 1,
#  '鄭泰諫': 1,
#  '天色': 1,
#  '急救': 2,
#  '俱奔避': 1,
#  '州牧': 1,
#  '然後用計': 1,
#  '小民': 1,
#  '求赦': 2,
#  '在手': 4,
#  '祝壽': 1,
#  '不分': 1,
#  '姓孫': 1,
#  '聲猶未': 1,
#  '面無事乎': 1,
#  '莊前': 1,
#  '親女': 1,
#  '騎弘馬': 1,
#  '不論': 1,
#  '劉虞平寇': 1,
#  '時陳宮': 1,
#  '下安': 1,
#  '其功': 1,
#  '寬懷': 1,
#  '叱布': 1,
#  '提防': 1,
#  '王者': 1,
#  '非仇': 1,
#  '身之計': 1,
#  '頭上': 1,
#  '年方': 3,
#  '已露': 1,
#  '農王': 1,
#  '蟬許': 1,
#  '不定': 1,
#  '奏何': 1,
#  '駢集': 1,
#  '名曰': 1,
#  '如旱': 1,
#  '把住': 1,
#  '城門外': 1,
#  '先皇': 1,
#  '定孫': 1,
#  '操覺': 1,
#  '回頭': 1,
#  '笙簧': 1,
#  '元年': 2,
#  '滅門': 2,
#  '不在側': 1,
#  '紹等懼': 1,
#  '可輕動': 2,
#  '良言': 1,
#  '降賊': 1,
#  '寸功': 1,
#  '軍自姓': 1,
#  '布大怒': 1,
#  '駕西幸': 1,
#  '覆姓': 1,
#  '太猛': 1,
#  '將何': 1,
#  '城郭': 1,
#  '悉皆': 1,
#  '無道': 2,
#  '反國': 1,
#  '念曰': 1,
#  '先鋒': 6,
#  '汝之力': 2,
#  '切勿': 2,
#  '高坡': 1,
#  '禽獸': 1,
#  '更衣': 2,
#  '本漢室': 1,
#  '韓馥之權': 1,
#  '背國': 1,
#  '田豐慌': 1,
#  '此來者': 1,
#  '而別': 1,
#  '棄官': 4,
#  '劉勝': 1,
#  '細詳': 1,
#  '行路': 1,
#  '忽折': 1,
#  '勸卓': 2,
#  '袁遺': 2,
#  '不語': 1,
#  '左右': 23,
#  '此長': 1,
#  '事濟': 1,
#  '其清者': 1,
#  '進調': 1,
#  '直進': 1,
#  '布交厚': 1,
#  '元老': 1,
#  '犯禁': 2,
#  '以將': 1,
#  '資財': 1,
#  '三十六年': 1,
#  '恐惹後人': 1,
#  '犯者': 2,
#  '坐中': 1,
#  '稱謝': 1,
#  '諭以': 1,
#  '非謙罪': 1,
#  '無限': 1,
#  '孤客': 1,
#  '母時': 1,
#  '武士': 9,
#  '各置': 1,
#  '發箭': 2,
#  '震開': 1,
#  '故托言': 1,
#  '尚自': 1,
#  '都督': 1,
#  '此天亡': 1,
#  '背主': 1,
#  '結義斬黃巾': 1,
#  '堅背': 1,
#  '奔涼州': 1,
#  '彼兵': 1,
#  '置酒': 6,
#  '韓遂': 9,
#  '劉焉': 7,
#  '無得': 1,
#  '恰待': 1,
#  '州郡': 2,
#  '使廷臣': 1,
#  '殷勤': 1,
#  '就席間': 1,
#  '裂汝以': 1,
#  '帝大驚': 1,
#  '願入': 1,
#  '發冠': 1,
#  '車騎將': 4,
#  '百寶妝': 1,
#  '呂布將': 2,
#  '顯官': 2,
#  '今先害': 1,
#  '黎民': 1,
#  '應付': 1,
#  '感恩': 1,
#  '宴之處': 1,
#  '上書': 1,
#  '出奇': 1,
#  '先伏': 1,
#  '帝令': 1,
#  '趕出': 1,
#  '各立': 1,
#  '戲汝': 1,
#  '淪喪': 1,
#  '可請汝兄': 1,
#  '出戰': 5,
#  '封弟': 2,
#  '責之': 1,
#  '北宮': 1,
#  '夜哭': 1,
#  '關純伏': 1,
#  '國母': 2,
#  '入獻': 1,
#  '諸侯興兵': 1,
#  '見原': 1,
#  '廝殺': 1,
#  '帝尊': 1,
#  '至華陰': 1,
#  '再議': 1,
#  '必順': 1,
#  '此天助': 1,
#  '殺得': 1,
#  '日誤': 1,
#  '然後圖': 1,
#  '良立': 1,
#  '張飛性': 1,
#  '劫寨': 1,
#  '孫堅次': 1,
#  '而致': 1,
#  '謀士逢紀': 1,
#  '卓大': 2,
#  '不勝': 2,
#  '姓祖': 1,
#  '何相戲': 1,
#  '盡棄': 1,
#  '北平': 3,
#  '滿地': 2,
#  '龔景': 3,
#  '錯下': 1,
#  '乃聚': 1,
#  '令良': 1,
#  '問其': 2,
#  '沛國': 2,
#  '喝退': 1,
#  '牧丹亭': 1,
#  '廟堂': 1,
#  '失此': 1,
#  '出血': 1,
#  '王協': 1,
#  '英雄': 13,
#  '今上': 4,
#  '整頓': 1,
#  '儒綁': 1,
#  '一行': 1,
#  '天使': 2,
#  '莫敢': 4,
#  '共寢': 1,
#  '死戰': 3,
#  '城門': 2,
#  '卓所立': 1,
#  '入宮': 8,
#  '曹公破': 1,
#  '成群': 1,
#  '何強': 1,
#  '罷兵': 3,
#  '之處': 3,
#  '卓賊': 1,
#  '舊日': 2,
#  '操聞言': 2,
#  '懼怕': 1,
#  '盜賊並': 1,
#  '解之': 1,
#  '當有': 1,
#  '貂蟬手': 1,
#  '五百': 13,
#  '兩軍齊': 2,
#  '病體': 1,
#  '軍士': 21,
#  '師事': 2,
#  '下令': 3,
#  '宦官': 7,
#  '九五': 2,
#  '勇略': 1,
#  '當先': 2,
#  '誠不若加': 1,
#  '進之謀': 1,
#  '引貂蟬': 1,
#  '聽政': 1,
#  '進兵': 5,
#  '同扶國家': 1,
#  '半酣': 2,
#  '回報': 7,
#  '病不出': 1,
#  '刀斧手': 2,
#  '布無心': 1,
#  '收兵': 2,
#  '之能': 1,
#  '涓埃': 1,
#  '卓聞言': 1,
#  '勝言': 1,
#  '擁入': 1,
#  '引軍暫': 1,
#  '名蓋': 1,
#  '活捉': 1,
#  '不惜': 1,
#  '龍床': 1,
#  '寇之志': 1,
#  '帝下': 1,
#  '猛將': 2,
#  '若何': 7,
#  '入後園': 1,
#  '連馬騰': 1,
#  '躍馬': 4,
#  '不肯': 6,
#  '可乘勢': 1,
#  '及甲': 1,
#  '不爛': 2,
#  '出園門': 1,
#  '向前': 5,
#  '乃差': 1,
#  '兒將': 1,
#  '之臣': 2,
#  '無計': 1,
#  '喜拜謝': 1,
#  '偎倚': 1,
#  '督郵先': 1,
#  '陶謙殺': 1,
#  '來京': 1,
#  '徒弟': 1,
#  '六月': 2,
#  '將軍何': 1,
#  '廣額': 1,
#  '與關': 2,
#  '汝若要': 1,
#  '五丈': 1,
#  '操軍大敗': 1,
#  '太后': 20,
#  '力扶漢': 1,
#  '鄄城': 1,
#  '祖大敗': 1,
#  '進而回': 1,
#  '樊稠去': 1,
#  '官惜': 1,
#  '各設': 1,
#  '本初': 9,
#  '見利': 1,
#  '人築': 1,
#  '乃東': 1,
#  '雄軍只': 1,
#  '操令': 1,
#  '高壘': 5,
#  '急進': 1,
#  '涿郡': 1,
#  '見機': 1,
#  '上街': 1,
#  '洪爐': 1,
#  '宜承洪業': 1,
#  '巧使': 1,
#  '領軍出': 1,
#  '願死': 1,
#  '四子': 2,
#  '陶謙遊': 1,
#  '李儒至': 1,
#  '許攸': 1,
#  '公取': 2,
#  '三公': 2,
#  '圖形': 1,
#  '章殿': 1,
#  '傍邊': 2,
#  '氣實': 1,
#  '聞將': 1,
#  '回寓': 1,
#  '來代將': 2,
#  '始初': 2,
#  '軍殺': 2,
#  '截孫堅': 1,
#  '勝於養': 1,
#  '接入': 2,
#  '義兵': 4,
#  '將軍一見': 1,
#  '何言無奈': 1,
#  '終成': 1,
#  '直殺': 2,
#  '上馬徑': 1,
#  '虔共薦': 1,
#  '能呼': 1,
#  '棄職': 1,
#  '卓將': 1,
#  '認玄德': 1,
#  '暗使': 2,
#  '老夫': 9,
#  '張而問': 1,
#  '以明': 1,
#  '社稷': 11,
#  '果然': 4,
#  '不若棄': 1,
#  '討區星': 1,
#  '紹驚得': 1,
#  '先父': 1,
#  '度日如年': 1,
#  '如車': 1,
#  '遠望': 2,
#  '中常': 6,
#  '布幾自誤': 1,
#  '帝非帝': 1,
#  '字伯': 1,
#  '牛輔': 9,
#  '延平': 1,
#  '張虎': 2,
#  '無虞': 1,
#  '活矣': 1,
#  '自戰敗': 1,
#  '只理會': 1,
#  '當下': 7,
#  '過者': 1,
#  '昔高': 1,
#  '反丁': 1,
#  '角得': 1,
#  '董後曰': 1,
#  '曹德及': 1,
#  '曹豹': 2,
#  '乃同': 1,
#  '三遷': 1,
#  '不用': 2,
#  '中部': 1,
#  '以言撫慰': 1,
#  '此關': 1,
#  '淚如泉': 1,
#  '骨悉': 1,
#  '盛德': 1,
#  '不必': 3,
#  '帳下': 3,
#  '卻常會': 1,
#  '異姓': 1,
#  '之大怒': 1,
#  '縛來': 1,
#  '立太子': 1,
#  '問門吏': 1,
#  '玄德遠': 1,
#  '何高見': 1,
#  '郭勝四個': 1,
#  '此玉': 1,
#  '百花': 2,
#  '騎花': 1,
#  '先將汝許': 1,
#  '某願助': 1,
#  '董氏宗': 1,
#  '巨富': 1,
#  '放入': 1,
#  '疏財仗': 1,
#  '諸侯皆言': 1,
#  '除洛陽': 2,
#  '未准': 1,
#  '堅令': 4,
#  '汝何': 3,
#  '已事': 1,
#  '張投': 1,
#  '侍衛': 1,
#  '機事': 1,
#  '伯喈': 1,
#  '堅隨即': 1,
#  '張邈': 4,
#  '領兵拔': 1,
#  '鎖著': 1,
#  '屯弘農': 1,
#  '召集': 1,
#  '布怒': 2,
#  '聽聞': 1,
#  '兄醉': 1,
#  '虎體': 2,
#  '難免': 1,
#  '漸漸': 1,
#  '群臣': 7,
#  '近侍': 1,
#  '時賊': 1,
#  '次收': 1,
#  '玉堂': 1,
#  '布入': 1,
#  '非命': 2,
#  '贈金銀': 1,
#  '其党馬元義': 1,
#  '允非': 1,
#  '言公鴆殺': 1,
#  '悶酒': 1,
#  '徑入': 5,
#  '唐周': 2,
#  '衣甲': 2,
#  '便問': 1,
#  '悲切': 1,
#  '問劉表借': 1,
#  '以助': 2,
#  '奔逃': 3,
#  '驅去': 1,
#  '密室': 1,
#  '日若': 1,
#  '安之至': 1,
#  '蟬出': 1,
#  '詞贊': 1,
#  '見布來': 1,
#  '公共': 1,
#  '車後厲': 1,
#  '方欲': 3,
#  '漫天': 1,
#  '特宣大將': 1,
#  '平原': 9,
#  '一子一女': 1,
#  '其如': 1,
#  '奉獻': 1,
#  '方驚避': 1,
#  '久住': 1,
#  '促裝': 1,
#  '鳴金': 4,
#  '十次': 1,
#  '尊意': 1,
#  '右有翼德': 1,
#  '民心': 3,
#  '其妹': 1,
#  '有濟': 1,
#  '善類': 1,
#  '孤陋': 1,
#  '公道': 1,
#  '不須': 1,
#  '義引': 2,
#  '一丈': 2,
#  '上建白': 1,
#  '退入': 2,
#  '雖然': 2,
#  '今匿': 1,
#  '相逼鄰': 1,
#  '氣高': 1,
#  '門外': 2,
#  '紅光': 1,
#  '允捧觴': 1,
#  '張伏': 1,
#  '朝賀': 1,
#  '潘鳳': 3,
#  '旗竿': 2,
#  '提縣': 1,
#  '兵圍': 1,
#  '口稱': 2,
#  '背後喊': 1,
#  '一處': 1,
#  '飛下': 2,
#  '相並': 1,
#  '定州': 2,
#  '少年': 9,
#  '兄長': 2,
#  '汝視': 1,
#  '道人': 1,
#  '可立': 1,
#  '兩傍': 1,
#  '起居': 1,
#  '肅拜': 1,
#  '手攀曲欄': 1,
#  '中石': 1,
#  '不意': 2,
#  '仰面': 3,
#  '有罪': 2,
#  '布軍與戰': 1,
#  '讒言': 1,
#  '王允運': 1,
#  '遮道': 1,
#  '宣卓入': 1,
#  '司徒': 18,
#  '西衝': 1,
#  '剿戮': 4,
#  '鞭大罵': 1,
#  '便出': 1,
#  '捉拿': 2,
#  '近卓': 1,
#  '召三': 1,
#  '牛輔喚': 1,
#  '近日': 3,
#  '四海': 2,
#  '相繼而入': 1,
#  '此賊': 3,
#  '施小策': 1,
#  '趕至翠花樓': 1,
#  '軍吏': 1,
#  '付布': 1,
#  '結連黃巾': 1,
#  '棄弓': 1,
#  '速決': 1,
#  '深深': 1,
#  '自寵': 1,
#  '進至長': 1,
#  '殺此': 2,
#  '奔入': 2,
#  '傳國玉璽': 1,
#  '殘虐': 1,
#  '沈吟': 1,
#  '萬人': 2,
#  '使人密': 2,
#  '當日': 4,
#  '越來': 1,
#  '過去': 3,
#  '迸流': 1,
#  '一驚': 2,
#  '大叫': 9,
#  '沙汰': 1,
#  '郵之頸': 1,
#  '必生': 1,
#  '朝門': 1,
#  '韓遂勒馬': 1,
#  '卓婿': 1,
#  '封太尉': 1,
#  '飛馬徑': 1,
#  '今可': 1,
#  '小方': 1,
#  '射時': 1,
#  '秀才': 1,
#  '卓必': 1,
#  '然身': 1,
#  '藏刀': 1,
#  '南陽': 3,
#  '既然': 1,
#  '現居何': 1,
#  '未有': 2,
#  '欲戰': 1,
#  '亦聘': 1,
#  '棄萬乘': 1,
#  '打死': 1,
#  '眼睛': 1,
#  '狂風': 1,
#  '雋班師': 1,
#  '鮑信': 9,
#  '右突': 2,
#  '人稱': 1,
#  '可破群': 1,
#  '攻習': 1,
#  '中設': 2,
#  '創殿': 1,
#  '軍馬列': 1,
#  '我奮': 1,
#  '大尉': 1,
#  '司空': 1,
#  '窺見': 1,
#  '浩大': 2,
#  '聲美譽': 1,
#  '平要術': 1,
#  '園門外': 1,
#  '將欲何': 1,
#  '應允': 2,
#  '氣象': 1,
#  '汝分': 1,
#  '率民': 1,
#  '文醜': 15,
#  '忘恩': 1,
#  '軍士圍': 1,
#  '引軍而出': 2,
#  '本部': 8,
#  '相近': 1,
#  '不佑': 1,
#  '於側': 2,
#  '坐久': 1,
#  '知事': 3,
#  '逸才': 1,
#  '兵馬': 1,
#  '拜紹': 1,
#  '今姑': 1,
#  '候誅': 1,
#  '反生': 1,
#  '可將': 1,
#  '宮中': 8,
#  '其頭': 1,
#  '策文': 1,
#  '卓入': 2,
#  '領三萬去': 1,
#  '昏時分': 2,
#  '與將': 1,
#  '欠身': 2,
#  '舟將': 1,
#  '張寶在': 2,
#  '收籍': 1,
#  '張濟引': 1,
#  '侍共議': 1,
#  '崔毅': 1,
#  '太師作': 1,
#  '無功': 1,
#  '丁建陽處': 1,
#  '加刑': 1,
#  '案下': 1,
#  '玄德大': 2,
#  '名普': 1,
#  '上縛布': 1,
#  '救軍到': 1,
#  '故久': 1,
#  '溫侯': 4,
#  '原系': 1,
#  '不恨': 1,
#  '中告': 1,
#  '斬賊': 1,
#  '別築': 1,
#  '此任': 1,
#  '虎威': 1,
#  '謀臣': 1,
#  '願相期': 1,
#  '將商議': 1,
#  '牽馬': 1,
#  '穢亂': 1,
#  '寶刀': 4,
#  '別部司': 1,
#  '因欲': 1,
#  '當保': 1,
#  '軍五萬': 1,
#  '莊主大驚': 1,
#  '此引': 1,
#  '舍之不義': 1,
#  '犯長': 2,
#  '若購': 1,
#  '議將': 1,
#  '大浪': 1,
#  '堅屍': 1,
#  '非棲鸞鳳': 1,
#  '因挽布手': 1,
#  '近因': 1,
#  '阿父': 1,
#  '之囚': 2,
#  '呼玄德': 1,
#  '進至': 1,
#  '山下': 3,
#  '勒馬門': 1,
#  '隗家': 1,
#  '堅歸寨': 1,
#  '半夜': 2,
#  '華雄戰': 1,
#  '差人將': 1,
#  '而行': 4,
#  '出國門': 1,
#  '天人共戮': 1,
#  '至於': 1,
#  '自此': 7,
#  '傍缺': 1,
#  '須別': 1,
#  '屍梟首': 1,
#  '精銳': 1,
#  '居喪': 1,
#  '舍一無謀': 1,
#  '普曰': 1,
#  '已避': 1,
#  '卓搶': 1,
#  '公憤': 1,
#  '袁術領': 1,
#  '待汝不薄': 1,
#  '中軍豎起': 1,
#  '新人': 1,
#  '李肅': 16,
#  '妖法': 1,
#  '兵乎': 1,
#  '此心': 1,
#  '京師': 2,
#  '之命': 1,
#  '張寶死': 2,
#  '一回': 3,
#  '姑恕': 1,
#  '發掘': 2,
#  '將軍若': 1,
#  '惱怒': 1,
#  '發榜': 1,
#  '城助戰': 1,
#  '問將': 1,
#  '無門路': 1,
#  '壯士': 1,
#  '諸侯內': 1,
#  '腹之交': 1,
#  '何意': 3,
#  '鄧茂': 2,
#  '相結': 1,
#  '能書符': 1,
#  '閉門': 1,
#  '宮禁': 1,
#  '許昌': 1,
#  '互相': 4,
#  '詔以': 1,
#  '齏粉': 2,
#  '二謀士': 1,
#  '窺視良': 1,
#  '急問': 1,
#  '一人入': 1,
#  '止樂': 1,
#  '固守': 1,
#  ...}

# %%
articlelist = sorted(articleDict.items(),key = lambda x:x[1], reverse = True) # 对词典中的词排序

# %%
# 输出词频的前N个
for i in range(100):
    print(articlelist[i])
# Out:
# ('袁紹', 57)
# ('天下', 53)
# ('玄德', 48)
# ('貂蟬', 37)
# ('太守', 36)
# ('朝廷', 32)
# ('孫堅', 31)
# ('不可', 31)
# ('次日', 26)
# ('商議', 25)
# ('引兵', 25)
# ('李儒', 25)
# ('天子', 24)
# ('左右', 23)
# ('太師', 22)
# ('玄德曰', 22)
# ('軍士', 21)
# ('校尉', 21)
# ('大喜', 21)
# ('今日', 21)
# ('太后', 20)
# ('王允', 20)
# ('何進', 20)
# ('二人', 19)
# ('司徒', 18)
# ('公孫瓚', 18)
# ('郭汜', 18)
# ('諸侯', 18)
# ('不能', 18)
# ('盧植', 17)
# ('朱雋', 17)
# ('百姓', 17)
# ('何人', 17)
# ('肅曰', 17)
# ('如此', 17)
# ('軍馬', 17)
# ('李肅', 16)
# ('百官', 16)
# ('張濟', 16)
# ('文醜', 15)
# ('如何', 15)
# ('何故', 15)
# ('留王', 15)
# ('皇甫嵩', 15)
# ('大事', 15)
# ('張飛', 15)
# ('張角', 15)
# ('正是', 14)
# ('劉表', 14)
# ('張梁', 14)
# ('刺史', 14)
# ('只見', 14)
# ('因此', 14)
# ('冀州', 14)
# ('袁術', 14)
# ('此人', 14)
# ('英雄', 13)
# ('五百', 13)
# ('曹嵩', 13)
# ('是夜', 13)
# ('五千', 13)
# ('不到', 13)
# ('樊稠', 13)
# ('將軍', 13)
# ('不得', 13)
# ('人馬', 12)
# ('性命', 12)
# ('李蒙', 12)
# ('華雄', 12)
# ('社稷', 11)
# ('趕來', 11)
# ('相府', 11)
# ('一人', 11)
# ('大臣', 11)
# ('一日', 11)
# ('蔡瑁', 11)
# ('星夜', 11)
# ('丞相', 11)
# ('張讓', 11)
# ('叔父', 11)
# ('主公', 11)
# ('三十', 11)
# ('只得', 10)
# ('再拜', 10)
# ('分解', 10)
# ('不知', 10)
# ('中郎將', 10)
# ('問曰', 10)
# ('不敢', 10)
# ('何太后', 10)
# ('一面', 10)
# ('下文', 10)
# ('乘勢', 10)
# ('相見', 10)
# ('忽見', 10)
# ('大呼', 10)
# ('不見', 10)
# ('三人', 10)
# ('一將', 9)
# ('洛陽', 9)
